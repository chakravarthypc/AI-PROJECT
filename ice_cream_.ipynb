# %% [markdown]
# <a href="https://colab.research.google.com/github/chakravarthypc/AI-PROJECT/blob/main/ice_cream_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# problem statement :
# To predict Ice Cream revenue based on temperature using simple linear regression.
#  This is Supervised learning problem with one feature(independent feature)-temperature and one target(dependent variable) - Revenue.
#  we aim to fit a straight line(regression line)that best describes the relation between temp and revenue.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("ICECREAM.csv")

# %%
df.head()
# Out:
#    Temperature  Ice Cream Profits
# 0           39              13.17
# 1           40              11.88
# 2           41              18.82
# 3           42              18.65
# 4           43              17.02

# %%
df.tail()
# Out:
#      Temperature  Ice Cream Profits
# 360           99              85.13
# 361           99              87.08
# 362           99              89.29
# 363          101              81.91
# 364          101              85.02

# %%
df.describe()
# Out:
#        Temperature  Ice Cream Profits
# count   365.000000         365.000000
# mean     71.980822          52.103616
# std      13.258510          15.989004
# min      39.000000          11.880000
# 25%      63.000000          40.650000
# 50%      73.000000          53.620000
# 75%      82.000000          63.630000
# max     101.000000          89.290000

# %%
df.isnull().sum()
# Out:
# Temperature          0
# Ice Cream Profits    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 365 entries, 0 to 364
# Data columns (total 2 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Temperature        365 non-null    int64
#  1   Ice Cream Profits  365 non-null    float64
# dtypes: float64(1), int64(1)
# memory usage: 5.8 KB

# %%
sns.scatterplot(x="Temperature",y="Ice Cream Profits",data=df)
plt.title("Temperature vs Revenue")
plt.xlabel("Temperature")
plt.ylabel("Ice Cream profits")
plt.show()

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
x = df[["Temperature"]]  # independent variable
y = df['Ice Cream Profits'] # dependent variable

# %% [markdown]
# # step : Train - Test split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=45)

# %% [markdown]
# #step : train a linear regression model

# %%
model = LinearRegression()

# %%
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
slope = model.coef_[0]
print(slope)
# Out:
# 1.2033918270251422

# %%
intercept = model.intercept_
print(intercept)
# Out:
# -34.52713792389267

# %% [markdown]
# Ice Cream Profits = -34.52+1.20* Temperature

# %%
predict = model.predict(x_test)

# %%
print(predict)
# Out:
# [50.91368179 65.35438372 52.11707362 49.71028997 54.52385728 17.21871064
#  65.35438372 37.6763717  37.6763717  58.13403276 43.69333083 42.48993901
#  82.2018693  24.4390616  68.9645592  25.64245343 61.74420824 19.62549429
#  44.89672266 76.18491016 52.11707362 59.33742458 67.76116737 59.33742458
#  66.55777555 32.86280439 30.45602074 44.89672266 41.28654718 67.76116737
#  58.13403276 66.55777555 36.47297987 44.89672266 55.7272491  47.30350631
#  78.59169382 68.9645592  47.30350631 64.15099189 47.30350631 16.01531881
#  73.77812651 50.91368179 28.04923708 67.76116737 31.65941256 59.33742458
#  84.60865295 30.45602074 42.48993901 38.87976352 66.55777555 52.11707362
#  37.6763717  54.52385728 53.32046545 70.16795103 53.32046545 66.55777555
#  36.47297987 54.52385728 61.74420824 58.13403276 80.99847747 58.13403276
#  46.10011449 58.13403276 66.55777555 49.71028997 43.69333083 64.15099189
#  67.76116737]

# %%
print("predicted _ice cream profit",predict)
# Out:
# predicted _ice cream profit [50.91368179 65.35438372 52.11707362 49.71028997 54.52385728 17.21871064
#  65.35438372 37.6763717  37.6763717  58.13403276 43.69333083 42.48993901
#  82.2018693  24.4390616  68.9645592  25.64245343 61.74420824 19.62549429
#  44.89672266 76.18491016 52.11707362 59.33742458 67.76116737 59.33742458
#  66.55777555 32.86280439 30.45602074 44.89672266 41.28654718 67.76116737
#  58.13403276 66.55777555 36.47297987 44.89672266 55.7272491  47.30350631
#  78.59169382 68.9645592  47.30350631 64.15099189 47.30350631 16.01531881
#  73.77812651 50.91368179 28.04923708 67.76116737 31.65941256 59.33742458
#  84.60865295 30.45602074 42.48993901 38.87976352 66.55777555 52.11707362
#  37.6763717  54.52385728 53.32046545 70.16795103 53.32046545 66.55777555
#  36.47297987 54.52385728 61.74420824 58.13403276 80.99847747 58.13403276
#  46.10011449 58.13403276 66.55777555 49.71028997 43.69333083 64.15099189
#  67.76116737]

# %% [markdown]
# #step:Model evaluation

# %%
mse = mean_squared_error(y_test, predict)
print(mse)
# Out:
# 4.824166540507425

# %%
import math

# %%
from math import sqrt

# %%
rmse = sqrt(mse)
print(rmse)
# Out:
# 2.196398538632601

# %%
r2 = r2_score(y_test, predict)
print(r2)
# Out:
# 0.9787794320233246

# %% [markdown]
# #Visualize the regression line

# %%
plt.scatter(x_test, y_test, color='blue', label='Actual Data')
plt.plot(x_train, model.predict(x_train), color='red', label='Regression Line')
plt.xlabel('Temperature')
plt.ylabel('Ice Cream Profits')
plt.title('Temperature vs Ice Cream Profits')
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# !pip install gradio

# %%
import gradio as gr

# %%
# prediction function for gradio

def IceCream_profits(temperature):

  prediction = model.predict(np.array[[temperature]])[0]
  return f"predicted Ice Cream profits: $ {prediction:.2f}"

# Build Gradio Interface
interface = gr.Interface( fn = Ice Cream_profits,
                         input = gr.number(label = "Enter the temperature"),
                          output = gr.TextBox(label = "predicted Ice ")
# Out:
#   File "/tmp/ipython-input-3-351017059.py", line 9
#     interface = gr.Interface( fn = Ice Cream_profits,
#                                    ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?
